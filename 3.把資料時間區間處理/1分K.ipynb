# %%
import pandas as pd 
import numpy as np
import time 
import os

path='C:/Users/MyUser/Desktop/DATABASE/'
path1='C:/Users/MyUser/Desktop/DATABASE/FUTURES/'
path2 = 'C:/Users/MyUser/Desktop/DATABASE/FUTURES/1min/'
path3 = 'C:/Users/MyUser/Desktop/DATABASE/Y/'
path4 = 'C:/Users/MyUser/Desktop/DATABASE/Y/1min/'

i = str(input('請輸入所需要日期格式YYYYMMDD'))

D1 = i[:4]
D2 = i[4:6]
D3 = i[6:8]


data = pd.DataFrame()
Yata = pd.DataFrame()
F = pd.read_csv(path1+i+'F.csv')
Y = pd.read_csv(path3+i+'Y.csv')

ft = pd.read_csv(path+'ft_1min.csv')
yt = pd.read_csv(path+'Y_1min.csv')

F.Date = pd.to_datetime(F.Date, format=" %H:%M:%S.%f")
Y.Date = pd.to_datetime(Y.Date, format=" %H:%M:%S.%f")




F.set_index(keys=["Date"], inplace=True)
Y.set_index(keys=["Date"], inplace=True)


t = 1
Volume = 0

m = F.merchandise[0]
p = F.Close[0]
#     Rprice = f2.Rprice[-1]
o = F.Open[0]
h = F.High[0]
l = F.Low[0]
#     vol = f2.vol.sum()
tv = F.Volume[0]
df2 = pd.DataFrame(data = [[D1+'-'+D2+'-'+D3+" 08:45:00",o,h,l,p,tv]],columns=["Date","Open",'High',"Low",'Close',"Volume"])
data = data.append(df2)


while t < len(ft.time) :
    s = ft.time[t-1]
    s = str.lstrip(s)
    e = ft.time[t]
    e = str.lstrip(e)
    f2 = F.between_time(s,e, include_end=False)
    m = f2.merchandise[0]
    p = f2.Close[0]
#     Rprice = f2.Rprice[0]
    o = f2.Open[0]
    h = f2.High[0]
    l = f2.Low[0]
#     vol = f2.vol.sum()
    tv = f2.vl.sum()+Volume
#     df2 = pd.DataFrame(data=[[i+" "+e, m, price, Rprice, Oprice, hprice, lprice, vol, tvol]],columns=["datetime","merchandise",'price',"Rprice","Oprice"," hprice",'lprice','vol',' tvol'])
    df2 = pd.DataFrame(data=[[D1+'-'+D2+'-'+D3+" "+e,o,h,l,p,tv]],columns=["Date","Open",'High',"Low",'Close',"Volume"])
    data = data.append(df2)
    t+=1
data.to_csv(path2+i+"F_1min.csv",index=False)
    

m = Y.merchandise[0]
p = Y.Close[0]
#     Rprice = f2.Rprice[-1]
o = Y.Open[0]
h = Y.High[0]
l = Y.Low[0]
#     vol = f2.vol.sum()
tv = Y.Volume[0]
df3 = pd.DataFrame(data=[[D1+'-'+D2+'-'+D3+" 09:00:00",o,h,l,p,tv]],columns=["Date","Open",'High',"Low",'Close',"Volume"])
Yata = Yata.append(df3)    
    
    
ttt = 1
Volume = 0


while ttt < len(yt.time) :

    if ttt<=265 :      
        tvol = 0
        s = yt.time[ttt-1]
        s = str.lstrip(s)
        e = yt.time[ttt]
        e = str.lstrip(e)
        y2 = Y.between_time(s,e, include_end=False)
        m = y2.merchandise[0]
        p = y2.Close[0]
    #     Rprice = f2.Rprice[0]
        o = y2.Open[0]
        h = y2.High[0]
        l = y2.Low[0]
    #     vol = f2.vol.sum()
        tv = y2.Volume[0]
    #     df3 = pd.DataFrame(data=[[i+" "+e, m, price, Rprice, Oprice, hprice, lprice, vol, tvol]],columns=["datetime","merchandise",'price',"Rprice","Oprice"," hprice",'lprice','totalmoney',' tvol'])
        df3 = pd.DataFrame(data=[[D1+'-'+D2+'-'+D3+" "+e,o,h,l,p,tv]],columns=["Date","Open",'High',"Low",'Close',"Volume"])
        Yata = Yata.append(df3)
        ttt+=1
    elif 265<ttt<270 :
        s = yt.time[ttt-1]
        s = str.lstrip(s)
        e = yt.time[ttt]
        e = str.lstrip(e)
        df3 = pd.DataFrame(data=[[D1+'-'+D2+'-'+D3+" "+e,o,h,l,p,tv]],columns=["Date","Open",'High',"Low",'Close',"Volume"])
        Yata = Yata.append(df3)
        ttt+=1

    else :
        m = Y.merchandise[-1]
        p = Y.Close[-1]
        Rprice = Y.Rprice[-1]
        o = Y.Open[-1]
        h = Y.High[-1]
        l = Y.Low[-1]
#         vol = y2.vol[-1]
        tv = Y.Volume[-1]
        df3 = pd.DataFrame(data=[[D1+'-'+D2+'-'+D3+" "+" 13:30:00.000",o,h,l,p,tv]],columns=["Date","Open",'High',"Low",'Close',"Volume"])
        Yata = Yata.append(df3)
        ttt+=1
Yata.to_csv(path4+i+"Y_1min.csv",index=False)
# Out:
# 請輸入所需要日期格式YYYYMMDD20200716
